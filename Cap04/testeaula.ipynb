# %%
frase = "   Esta frase é muito legal.         "
print(len(frase))
# Out:
# 37

# %%
fraseajuste = frase.strip()
print(len(fraseajuste))
# Out:
# 25

# %%
print(fraseajuste.upper())
print(fraseajuste.lower())
# Out:
# ESTA FRASE É MUITO LEGAL.
# esta frase é muito legal.

# %%
print(fraseajuste.replace('frase', 'sentença'))
# Out:
# Esta sentença é muito legal.

# %%
print(fraseajuste[0])
print(fraseajuste[5:10])
# Out:
# E
# frase
